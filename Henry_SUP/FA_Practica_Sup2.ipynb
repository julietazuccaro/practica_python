# %% [markdown]
# ## EJERCICIO 2 - “Sistema automático de seguimiento de estudiantes”
# El objetivo es que practiquen:
# - múltiples inputs
# - validación de datos
# - operadores lógicos (and, or)
# - varios if / elif / else combinados
# - cálculos con más de una variable
# - pensar reglas más realistas

# %% [markdown]
# ### Parte 1 – Datos del estudiante

# %%
nombre = input("¿Cómo te llamás? ")
edad = int(input("¿Cuántos años tenés? "))
clases_vistas = int(input("¿Cuántas clases viste esta semana? "))
horas_extra = float(input("¿Cuántas horas extra estudiaste por tu cuenta? "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 nombre = input("¿Cómo te llamás? ")
# ----> 2 edad = int(input("¿Cuántos años tenés? "))
#       3 clases_vistas = int(input("¿Cuántas clases viste esta semana? "))
#       4 horas_extra = float(input("¿Cuántas horas extra estudiaste por tu cuenta? "))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### Parte 2 – Validación básica

# %%
if edad < 0 or edad > 120:
    print("Edad inválida")
    
if clases_vistas < 0:
    print("Cantidad de clases inválida")
    
if horas_extra < 0:
    print("Las horas no pueden ser negativas")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 if edad < 0 or edad > 120:
#       2     print("Edad inválida")
#       4 if clases_vistas < 0:
#
# NameError: name 'edad' is not defined

# %% [markdown]
# ### Parte 3 – Clasificación por edad

# %%
if edad < 13:
    categoria_edad = "niño/a"
elif edad < 18:
    categoria_edad = "adolescente"
else:
    categoria_edad = "adulto/a"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 if edad < 13:
#       2     categoria_edad = "niño/a"
#       3 elif edad < 18:
#
# NameError: name 'edad' is not defined

# %% [markdown]
# ### Parte 4 – Cálculo de dedicación total

# %%
horas_por_clase = 2
horas_totales = clases_vistas * horas_por_clase + horas_extra

print("Horas totales de estudio:", horas_totales)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 horas_por_clase = 2
# ----> 2 horas_totales = clases_vistas * horas_por_clase + horas_extra
#       4 print("Horas totales de estudio:", horas_totales)
#
# NameError: name 'clases_vistas' is not defined

# %% [markdown]
# ### Parte 5 – Evaluación del compromiso

# %%
if clases_vistas >= 3 and horas_totales >= 6:
    estado = "Compromiso ALTO"
elif clases_vistas >= 2 and horas_totales >= 4:
    estado = "Compromiso MEDIO"
else:
    estado = "Compromiso BAJO"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 if clases_vistas >= 3 and horas_totales >= 6:
#       2     estado = "Compromiso ALTO"
#       3 elif clases_vistas >= 2 and horas_totales >= 4:
#
# NameError: name 'clases_vistas' is not defined

# %% [markdown]
# Pregunta:
#
# - ¿Por qué usamos and y no solo una condición?

# %% [markdown]
# ### Parte 6 – Mensaje personalizado final

# %%
print("\n📊 REPORTE SEMANAL")
print("Estudiante:", nombre)
print("Edad:", edad, "-", categoria_edad)
print("Clases vistas:", clases_vistas)
print("Horas extra:", horas_extra)
print("Total de horas de estudio:", horas_totales)
print("Nivel de compromiso:", estado)
# Out:
# 📊 REPORTE SEMANAL
# Estudiante:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 print("\n📊 REPORTE SEMANAL")
#       2 print("Estudiante:", nombre)
# ----> 3 print("Edad:", edad, "-", categoria_edad)
#       4 print("Clases vistas:", clases_vistas)
#       5 print("Horas extra:", horas_extra)
#
# NameError: name 'edad' is not defined

# %% [markdown]
# ### Parte 7 – Reglas especiales

# %%
if edad < 18 and horas_totales >= 10:
    print("¡Impresionante dedicación para tu edad! 🌟")

if clases_vistas == 0:
    print("⚠️ Esta semana no registrás clases vistas")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 if edad < 18 and horas_totales >= 10:
#       2     print("¡Impresionante dedicación para tu edad! 🌟")
#       4 if clases_vistas == 0:
#
# NameError: name 'edad' is not defined

# %% [markdown]
# Preguntas:
#
# - ¿Puede alguien ver 5 clases pero tener pocas horas totales?
# - ¿Puede alguien ver pocas clases pero estudiar mucho?
# - ¿Por qué ya no alcanza con un solo if?
# - ¿Este programa podría usarse para enviar reportes automáticos?
# - ¿Qué datos más podríamos agregar? (sueño, ejercicios, proyectos)
