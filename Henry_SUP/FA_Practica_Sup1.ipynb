# %% [markdown]
# EJERCICIO 1 – “Tomar decisiones con datos”
#
# Objetivo
# Que entiendan:
# - variables
# - input
# - operaciones
# - if / else
# - que el código decide según condiciones

# %%
nombre = input("Cómo te llamás? ")
edad = int(input("Cuántos años tenés?"))

print("Hola", nombre)
print("Edad registrada:", edad)
# Out:
# Hola Facundo
# Edad registrada: 18

# %% [markdown]
# Preguntas:
#
# - Por qué creen que usamos int()?
# - Qué pasaría si no lo ponemos?

# %%
if edad >= 18:
    print("Sos mayor de edad")
else:
    print("Sos menor de edad")
# Out:
# Sos mayor de edad

# %% [markdown]
# Preguntas:
#
# - Qué pasa si pongo 17?
# - Y si pongo 18?

# %%
if edad < 13:
    print("Sos menor de 13")
elif edad < 18:
    print("Sos adolescente")
else:
    print("Sos adulto")
# Out:
# Sos adulto

# %% [markdown]
# Preguntas:
#
# - Se ejecutan todas las condiciones?
# - En qué orden se leen?

# %%
clases_vistas = int(input("Cuántas clases viste esta semana? "))

if clases_vistas >= 3:
    print("Buen ritmo 💪")
else:
    print("Ojo, tratá de ponerte al día")
# Out:
# Buen ritmo 💪

# %% [markdown]
# Preguntas:
#
# - Esto podría ser un mensaje automático?
# - Quién decide el criterio?

# %%
horas_por_clase = 2
total_horas = clases_vistas * horas_por_clase

print("Horas totales de estudio:", total_horas)

if total_horas >= 6:
    print("Excelente dedicación")
else:
    print("Podés mejorar el ritmo")
# Out:
# Horas totales de estudio: 6
# Excelente dedicación

# %% [markdown]
# Preguntas:
#
# - Esto podría ser un mensaje automático?
# - Quién decide el criterio?

# %%
print(nombre, "estuviste", total_horas, "horas estudiando esta semana")
# Out:
# Facundo estuviste 6 horas estudiando esta semana

# %% [markdown]
# Pregunta:
#
# - Esto sería imposible de hacer a mano para 500 alumnos?

# %%
if clases_vistas = 3:
    print("Viste 3 clases")
# Out:
#   Cell In[11], line 1
#     if clases_vistas = 3:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# Preguntas:
#
# - Qué creen que pasó?
# - Qué nos está diciendo el error?

# %%
if clases_vistas == 3:
    print("Viste exactamente 3 clases")
# Out:
# Viste exactamente 3 clases
