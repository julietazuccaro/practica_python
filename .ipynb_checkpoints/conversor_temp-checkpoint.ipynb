# %% [markdown]
# # Conversor de temperatura de celcius a fahrenheit
# **F = C × 1.8 + 32.**

# %%
#entrada
gradosCelsius = float(input())

#proceso
gradosFahr = gradosCelsius * 1.8 + 32

#salida
print(f"Conversión a fahr: {gradosFahr:.2f}")
# Out:
#  1.234543256
# Conversión a fahr: 34.22
