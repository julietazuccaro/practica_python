# %%
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def Presentarse(self):
        print('mi nombre es', self.nombre, 'y mi edad es', self.edad )
    

class Estudiante(Persona):
    def __init__(self, nombre, edad, grado):
        super().__init__(nombre, edad)
        self.grado = grado

    def grado_de_estudios(self):
        print(' mi grado es:', self.grado)    

persona1 = Estudiante('Ana', 26, 'tercero')
persona1.Presentarse()
persona1.grado_de_estudios()
# Out:
# mi nombre es Ana y mi edad es 26
#  mi grado es: tercero
