# %% [markdown]
# ### Exercise 1: Create a function in Python
# ##### Write a program to create a function that takes two arguments, name and age, and prints their values.

# %%
def identidad(nombre, edad):
        frase = f"tu nombre es: {nombre} y tu edad es : {edad}"
        return frase
identidad("Julieta", 36)
# Out:
# 'tu nombre es: Julieta y tu edad es : 36'

# %% [markdown]
# ### Exercise 2: Create a function with variable length of arguments

# %%
def func1(*args):
    print(*args)
    return
func1(20,40,60)
# Out:
# 20 40 60
