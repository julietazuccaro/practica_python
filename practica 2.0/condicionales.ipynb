# %%
n = int(input("ingrese un número natural"))
if n%2==0: 
    salida = "{} es par".format(n)
    print(salida)
else:
    salida = "{} es impar".format(n)
    print(salida)
# Out:
# ingrese un número natural 13
# 13 es impar

# %%
edad =  17
if edad >= 18:
    print("Eres mayor de edad")
elif edad >= 13: # Si no es mayor de edad, verifica que es adolescente
    print("Eres adolescente")
else: # Si ninguna de las anteriores es verdadera
    print("Eres un niño")
# Out:
# Eres adolescente
